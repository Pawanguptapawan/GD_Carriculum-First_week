# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
stats.norm.cdf(0)
# Out:
# np.float64(0.5)

# %%
stats.binom(10,0.5).pmf(3)
# Out:
# np.float64(0.11718750000000004)

# %% [markdown]
# ## Univariate data analysis.
